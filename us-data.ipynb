# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
pd.read_csv('https://data.humdata.org/hxlproxy/api/data-preview.csv?url=https%3A%2F%2Fraw.githubusercontent.com%2FCSSEGISandData%2FCOVID-19%2Fmaster%2Fcsse_covid_19_data%2Fcsse_covid_19_time_series%2Ftime_series_covid19_confirmed_global.csv&filename=time_series_covid19_confirmed_global.csv',index_col=0)
# Out:
#                        Country/Region        Lat       Long  1/22/20  1/23/20  \
# Province/State
# NaN                       Afghanistan  33.000000  65.000000        0        0
# NaN                           Albania  41.153300  20.168300        0        0
# NaN                           Algeria  28.033900   1.659600        0        0
# NaN                           Andorra  42.506300   1.521800        0        0
# NaN                            Angola -11.202700  17.873900        0        0
# ...                               ...        ...        ...      ...      ...
# NaN             Sao Tome and Principe   0.186360   6.613081        0        0
# NaN                             Yemen  15.552727  48.516388        0        0
# NaN                           Comoros -11.645500  43.333300        0        0
# NaN                        Tajikistan  38.861034  71.276093        0        0
# NaN                           Lesotho -29.609988  28.233608        0        0
#
#                 1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  ...  5/29/20  \
# Province/State                                               ...
# NaN                   0        0        0        0        0  ...    13659
# NaN                   0        0        0        0        0  ...     1099
# NaN                   0        0        0        0        0  ...     9134
# NaN                   0        0        0        0        0  ...      764
# NaN                   0        0        0        0        0  ...       81
# ...                 ...      ...      ...      ...      ...  ...      ...
# NaN                   0        0        0        0        0  ...      463
# NaN                   0        0        0        0        0  ...      283
# NaN                   0        0        0        0        0  ...       87
# NaN                   0        0        0        0        0  ...     3686
# NaN                   0        0        0        0        0  ...        2
#
#                 5/30/20  5/31/20  6/1/20  6/2/20  6/3/20  6/4/20  6/5/20  \
# Province/State
# NaN               14525    15205   15750   16509   17267   18054   18969
# NaN                1122     1137    1143    1164    1184    1197    1212
# NaN                9267     9394    9513    9626    9733    9831    9935
# NaN                 764      764     765     844     851     852     852
# NaN                  84       86      86      86      86      86      86
# ...                 ...      ...     ...     ...     ...     ...     ...
# NaN                 479      483     484     484     484     485     499
# NaN                 310      323     354     399     419     453     469
# NaN                 106      106     106     132     132     132     132
# NaN                3807     3930    4013    4100    4191    4289    4370
# NaN                   2        2       2       2       4       4       4
#
#                 6/6/20  6/7/20
# Province/State
# NaN              19551   20342
# NaN               1232    1246
# NaN              10050   10154
# NaN                852     852
# NaN                 88      91
# ...                ...     ...
# NaN                499     513
# NaN                482     484
# NaN                141     141
# NaN               4453    4529
# NaN                  4       4
#
# [266 rows x 141 columns]

# %%
g=_.loc[_['Country/Region'] == "India"]

# %%
g
# Out:
#                Country/Region   Lat  Long  1/22/20  1/23/20  1/24/20  1/25/20  \
# Province/State
# NaN                     India  21.0  78.0        0        0        0        0
#
#                 1/26/20  1/27/20  1/28/20  ...  5/29/20  5/30/20  5/31/20  \
# Province/State                             ...
# NaN                   0        0        0  ...   173491   181827   190609
#
#                 6/1/20  6/2/20  6/3/20  6/4/20  6/5/20  6/6/20  6/7/20
# Province/State
# NaN             198370  207191  216824  226713  236184  246622  257486
#
# [1 rows x 141 columns]

# %%
f =g.iloc[0,4:]

# %%
plt.plot(range(0,len(f)),f)
plt.yscale('log')

# %%
pd.read_csv('https://data.humdata.org/hxlproxy/api/data-preview.csv?url=https%3A%2F%2Fraw.githubusercontent.com%2FCSSEGISandData%2FCOVID-19%2Fmaster%2Fcsse_covid_19_data%2Fcsse_covid_19_time_series%2Ftime_series_covid19_recovered_global.csv&filename=time_series_covid19_recovered_global.csv',index_col=0)
# Out:
#                        Country/Region        Lat       Long  1/22/20  1/23/20  \
# Province/State
# NaN                       Afghanistan  33.000000  65.000000        0        0
# NaN                           Albania  41.153300  20.168300        0        0
# NaN                           Algeria  28.033900   1.659600        0        0
# NaN                           Andorra  42.506300   1.521800        0        0
# NaN                            Angola -11.202700  17.873900        0        0
# ...                               ...        ...        ...      ...      ...
# NaN             Sao Tome and Principe   0.186360   6.613081        0        0
# NaN                             Yemen  15.552727  48.516388        0        0
# NaN                           Comoros -11.645500  43.333300        0        0
# NaN                        Tajikistan  38.861034  71.276093        0        0
# NaN                           Lesotho -29.609988  28.233608        0        0
#
#                 1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  ...  5/29/20  \
# Province/State                                               ...
# NaN                   0        0        0        0        0  ...     1259
# NaN                   0        0        0        0        0  ...      851
# NaN                   0        0        0        0        0  ...     5422
# NaN                   0        0        0        0        0  ...      684
# NaN                   0        0        0        0        0  ...       18
# ...                 ...      ...      ...      ...      ...  ...      ...
# NaN                   0        0        0        0        0  ...       68
# NaN                   0        0        0        0        0  ...       11
# NaN                   0        0        0        0        0  ...       24
# NaN                   0        0        0        0        0  ...     1769
# NaN                   0        0        0        0        0  ...        1
#
#                 5/30/20  5/31/20  6/1/20  6/2/20  6/3/20  6/4/20  6/5/20  \
# Province/State
# NaN                1303     1328    1428    1450    1522    1585    1762
# NaN                 857      872     877     891     898     898     910
# NaN                5549     5748    5894    6067    6218    6297    6453
# NaN                 692      694     698     733     735     738     741
# NaN                  18       18      18      18      18      18      21
# ...                 ...      ...     ...     ...     ...     ...     ...
# NaN                  68       68      68      68      68      68      68
# NaN                  13       14      14      15      17      17      23
# NaN                  26       26      26      27      27      55      55
# NaN                1865     2004    2089    2217    2347    2401    2491
# NaN                   1        1       1       1       2       2       2
#
#                 6/6/20  6/7/20
# Province/State
# NaN               1830    1875
# NaN                925     938
# NaN               6631    6717
# NaN                741     744
# NaN                 24      24
# ...                ...     ...
# NaN                 68      68
# NaN                 23      23
# NaN                 67      67
# NaN               2583    2673
# NaN                  2       2
#
# [253 rows x 141 columns]

# %%
p=_.loc[_['Country/Region'] == "India"]

# %%
pd.read_csv('https://data.humdata.org/hxlproxy/api/data-preview.csv?url=https%3A%2F%2Fraw.githubusercontent.com%2FCSSEGISandData%2FCOVID-19%2Fmaster%2Fcsse_covid_19_data%2Fcsse_covid_19_time_series%2Ftime_series_covid19_deaths_global.csv&filename=time_series_covid19_deaths_global.csv',index_col=0)
# Out:
#                        Country/Region        Lat       Long  1/22/20  1/23/20  \
# Province/State
# NaN                       Afghanistan  33.000000  65.000000        0        0
# NaN                           Albania  41.153300  20.168300        0        0
# NaN                           Algeria  28.033900   1.659600        0        0
# NaN                           Andorra  42.506300   1.521800        0        0
# NaN                            Angola -11.202700  17.873900        0        0
# ...                               ...        ...        ...      ...      ...
# NaN             Sao Tome and Principe   0.186360   6.613081        0        0
# NaN                             Yemen  15.552727  48.516388        0        0
# NaN                           Comoros -11.645500  43.333300        0        0
# NaN                        Tajikistan  38.861034  71.276093        0        0
# NaN                           Lesotho -29.609988  28.233608        0        0
#
#                 1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  ...  5/29/20  \
# Province/State                                               ...
# NaN                   0        0        0        0        0  ...      246
# NaN                   0        0        0        0        0  ...       33
# NaN                   0        0        0        0        0  ...      638
# NaN                   0        0        0        0        0  ...       51
# NaN                   0        0        0        0        0  ...        4
# ...                 ...      ...      ...      ...      ...  ...      ...
# NaN                   0        0        0        0        0  ...       12
# NaN                   0        0        0        0        0  ...       65
# NaN                   0        0        0        0        0  ...        2
# NaN                   0        0        0        0        0  ...       47
# NaN                   0        0        0        0        0  ...        0
#
#                 5/30/20  5/31/20  6/1/20  6/2/20  6/3/20  6/4/20  6/5/20  \
# Province/State
# NaN                 249      257     265     270     294     300     309
# NaN                  33       33      33      33      33      33      33
# NaN                 646      653     661     667     673     681     690
# NaN                  51       51      51      51      51      51      51
# NaN                   4        4       4       4       4       4       4
# ...                 ...      ...     ...     ...     ...     ...     ...
# NaN                  12       12      12      12      12      12      12
# NaN                  77       80      84      87      95     103     111
# NaN                   2        2       2       2       2       2       2
# NaN                  47       47      47      47      48      48      48
# NaN                   0        0       0       0       0       0       0
#
#                 6/6/20  6/7/20
# Province/State
# NaN                327     357
# NaN                 34      34
# NaN                698     707
# NaN                 51      51
# NaN                  4       4
# ...                ...     ...
# NaN                 12      12
# NaN                111     112
# NaN                  2       2
# NaN                 48      48
# NaN                  0       0
#
# [266 rows x 141 columns]

# %%
fd= _.loc[_['Country/Region'] == "India"]

# %%
s=p.iloc[0,4:]
fdf = fd.iloc[0,4:]
plt.plot(range(0,len(f)),f,label='Confirmed')
plt.plot(range(0,len(s)),s,label='Recoveries')
plt.plot(range(0,len(fdf)),fdf,label='Deaths')
plt.xlabel('Days Since R0')
plt.ylabel('Cases (Log Scale)')
plt.title('Covid Cases in India')
legend = plt.legend()
plt.yscale('log')
plt.savefig('un1.png')

# %%
pd.read_csv('https://data.humdata.org/hxlproxy/api/data-preview.csv?url=https%3A%2F%2Fraw.githubusercontent.com%2FCSSEGISandData%2FCOVID-19%2Fmaster%2Fcsse_covid_19_data%2Fcsse_covid_19_time_series%2Ftime_series_covid19_confirmed_global.csv&filename=time_series_covid19_confirmed_global.csv',index_col=0)
# Out:
#                        Country/Region        Lat       Long  1/22/20  1/23/20  \
# Province/State
# NaN                       Afghanistan  33.000000  65.000000        0        0
# NaN                           Albania  41.153300  20.168300        0        0
# NaN                           Algeria  28.033900   1.659600        0        0
# NaN                           Andorra  42.506300   1.521800        0        0
# NaN                            Angola -11.202700  17.873900        0        0
# ...                               ...        ...        ...      ...      ...
# NaN             Sao Tome and Principe   0.186360   6.613081        0        0
# NaN                             Yemen  15.552727  48.516388        0        0
# NaN                           Comoros -11.645500  43.333300        0        0
# NaN                        Tajikistan  38.861034  71.276093        0        0
# NaN                           Lesotho -29.609988  28.233608        0        0
#
#                 1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  ...  5/30/20  \
# Province/State                                               ...
# NaN                   0        0        0        0        0  ...    14525
# NaN                   0        0        0        0        0  ...     1122
# NaN                   0        0        0        0        0  ...     9267
# NaN                   0        0        0        0        0  ...      764
# NaN                   0        0        0        0        0  ...       84
# ...                 ...      ...      ...      ...      ...  ...      ...
# NaN                   0        0        0        0        0  ...      479
# NaN                   0        0        0        0        0  ...      310
# NaN                   0        0        0        0        0  ...      106
# NaN                   0        0        0        0        0  ...     3807
# NaN                   0        0        0        0        0  ...        2
#
#                 5/31/20  6/1/20  6/2/20  6/3/20  6/4/20  6/5/20  6/6/20  \
# Province/State
# NaN               15205   15750   16509   17267   18054   18969   19551
# NaN                1137    1143    1164    1184    1197    1212    1232
# NaN                9394    9513    9626    9733    9831    9935   10050
# NaN                 764     765     844     851     852     852     852
# NaN                  86      86      86      86      86      86      88
# ...                 ...     ...     ...     ...     ...     ...     ...
# NaN                 483     484     484     484     485     499     499
# NaN                 323     354     399     419     453     469     482
# NaN                 106     106     132     132     132     132     141
# NaN                3930    4013    4100    4191    4289    4370    4453
# NaN                   2       2       2       4       4       4       4
#
#                 6/7/20  6/8/20
# Province/State
# NaN              20342   20917
# NaN               1246    1263
# NaN              10154   10265
# NaN                852     852
# NaN                 91      92
# ...                ...     ...
# NaN                513     513
# NaN                484     496
# NaN                141     141
# NaN               4529    4609
# NaN                  4       4
#
# [266 rows x 142 columns]

# %%
_.sum(axis=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-69a91062a784> in <module>
# ----> 1 _.sum(axis=0)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in stat_func(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   11180             skipna=skipna,
#   11181             numeric_only=numeric_only,
# > 11182             min_count=min_count,
#   11183         )
#   11184
#
# /usr/local/lib/python3.7/site-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3889                 )
#    3890             with np.errstate(all="ignore"):
# -> 3891                 return op(delegate, skipna=skipna, **kwds)
#    3892
#    3893         # TODO(EA) dispatch to Index
#
# /usr/local/lib/python3.7/site-packages/pandas/core/nanops.py in _f(*args, **kwargs)
#      67             try:
#      68                 with np.errstate(invalid="ignore"):
# ---> 69                     return f(*args, **kwargs)
#      70             except ValueError as e:
#      71                 # we want to transform an object array
#
# /usr/local/lib/python3.7/site-packages/pandas/core/nanops.py in nansum(values, axis, skipna, min_count, mask)
#     491     elif is_timedelta64_dtype(dtype):
#     492         dtype_sum = np.float64
# --> 493     the_sum = values.sum(axis, dtype=dtype_sum)
#     494     the_sum = _maybe_null_out(the_sum, axis, mask, values.shape, min_count=min_count)
#     495
#
# /usr/local/lib/python3.7/site-packages/numpy/core/_methods.py in _sum(a, axis, dtype, out, keepdims, initial, where)
#      36 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      37          initial=_NoValue, where=True):
# ---> 38     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#      39
#      40 def _prod(a, axis=None, dtype=None, out=None, keepdims=False,
#
# TypeError: can only concatenate str (not "float") to str

# %%
_[2:]
# Out:
# Series([], dtype: object)
